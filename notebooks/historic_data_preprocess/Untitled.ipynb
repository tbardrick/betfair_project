# %%
from data_utils import datadict

# %%
d = datadict

# %%
d
# Out:
# {'Time': [],
#  'MarketId': [],
#  'Status': [],
#  'Inplay': [],
#  'SelectionId': [],
#  'LastPriceTraded': [],
#  'TotalMatched': [],
#  'BSP': [],
#  'AdjFactor': [],
#  'RunnerStatus': [],
#  'MktTotalMatched': [],
#  'RaceInfo': [],
#  'Venue': [],
#  'BackSize': [],
#  'BackPrice': [],
#  'LayPrice': [],
#  'LaySize': []}

# %%
import numpy as np

# %%
np.concatenate(([-np.inf],np.arange(-100080, 120, 120)))
# Out:
# array([    -inf, -100080.,  -99960.,  -99840.,  -99720.,  -99600.,
#         -99480.,  -99360.,  -99240.,  -99120.,  -99000.,  -98880.,
#         -98760.,  -98640.,  -98520.,  -98400.,  -98280.,  -98160.,
#         -98040.,  -97920.,  -97800.,  -97680.,  -97560.,  -97440.,
#         -97320.,  -97200.,  -97080.,  -96960.,  -96840.,  -96720.,
#         -96600.,  -96480.,  -96360.,  -96240.,  -96120.,  -96000.,
#         -95880.,  -95760.,  -95640.,  -95520.,  -95400.,  -95280.,
#         -95160.,  -95040.,  -94920.,  -94800.,  -94680.,  -94560.,
#         -94440.,  -94320.,  -94200.,  -94080.,  -93960.,  -93840.,
#         -93720.,  -93600.,  -93480.,  -93360.,  -93240.,  -93120.,
#         -93000.,  -92880.,  -92760.,  -92640.,  -92520.,  -92400.,
#         -92280.,  -92160.,  -92040.,  -91920.,  -91800.,  -91680.,
#         -91560.,  -91440.,  -91320.,  -91200.,  -91080.,  -90960.,
#         -90840.,  -90720.,  -90600.,  -90480.,  -90360.,  -90240.,
# ...

# %%
np.concatenate((np.arange(0, , 120), [np.inf]))
# Out:
# array([      -inf, -1.000e+05, -9.988e+04, -9.976e+04, -9.964e+04,
#        -9.952e+04, -9.940e+04, -9.928e+04, -9.916e+04, -9.904e+04,
#        -9.892e+04, -9.880e+04, -9.868e+04, -9.856e+04, -9.844e+04,
#        -9.832e+04, -9.820e+04, -9.808e+04, -9.796e+04, -9.784e+04,
#        -9.772e+04, -9.760e+04, -9.748e+04, -9.736e+04, -9.724e+04,
#        -9.712e+04, -9.700e+04, -9.688e+04, -9.676e+04, -9.664e+04,
#        -9.652e+04, -9.640e+04, -9.628e+04, -9.616e+04, -9.604e+04,
#        -9.592e+04, -9.580e+04, -9.568e+04, -9.556e+04, -9.544e+04,
#        -9.532e+04, -9.520e+04, -9.508e+04, -9.496e+04, -9.484e+04,
#        -9.472e+04, -9.460e+04, -9.448e+04, -9.436e+04, -9.424e+04,
#        -9.412e+04, -9.400e+04, -9.388e+04, -9.376e+04, -9.364e+04,
#        -9.352e+04, -9.340e+04, -9.328e+04, -9.316e+04, -9.304e+04,
#        -9.292e+04, -9.280e+04, -9.268e+04, -9.256e+04, -9.244e+04,
#        -9.232e+04, -9.220e+04, -9.208e+04, -9.196e+04, -9.184e+04,
# ...
