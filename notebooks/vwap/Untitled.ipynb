# %%
import pandas as pd
import numpy as np

# %%
- Price made up of backers and layers

# %%
'we want to back' - at what price and at what volume/relative confidence

# %%
- Where backers and layers 'meet' determines the market price

# %%
Where the demand of the backers (lower limits) meets the supply of the layers (the upper limit)

# %%
- What we are interested in is where how each price point is determined? What makes up each side.

# %%
So how do we quantify how each side is constitued? and more importantly is this predictive of price moves?

# %%
- What featues can be created and how we define future price moves?

# %% [markdown]
# ---

# %%
# pick number between 1 and 1000
np.random.choice([0,1000], 1)
# Out:
# array([0])

# %%
ticks = np.concatenate([np.arange(1.01, 2.01, 0.01),
                        np.arange(2.02, 3.02, 0.02),
                        np.arange(3.05, 4.05, 0.05),
                        np.arange(4.1, 6.1, 0.1),
                        np.arange(6.2, 10.2, 0.2),
                        np.arange(10.5, 20.5, 0.5),
                        np.arange(21, 31, 1),
                        np.arange(32, 52, 2),
                        np.arange(55, 105, 5),
                        np.arange(110, 1010, 10)])

# %%
# pick a price
p = round(np.random.choice(ticks), 2)

# simulate some volume for this price


# simulate a volume for eahc of the next 10-30 prices ticks

#

# %%
Simulate whole market
- random pick first price

# %%
how to generate an acurate an accurate distiubtion for the volumes?

# %%
def find_closest_tick(price):
    '''
    Given some price, this returnds the 'nearest' Betfair price
    Note : 0.5 will round down
    '''
    
    import numpy as np
    
    ticks = np.concatenate([np.arange(1.01, 2.01, 0.01),
                            np.arange(2.02, 3.02, 0.02),
                            np.arange(3.05, 4.05, 0.05),
                            np.arange(4.1, 6.1, 0.1),
                            np.arange(6.2, 10.2, 0.2),
                            np.arange(10.5, 20.5, 0.5),
                            np.arange(21, 31, 1),
                            np.arange(32, 52, 2),
                            np.arange(55, 105, 5),
                            np.arange(110, 1010, 10)])
    
    idx = (np.abs(ticks - price)).argmin() 
    
    price = round(ticks[idx], 2) 
    
    
    
    return price

# %%
find_closest_tick(5)
# Out:
# 5.0
