# %%
# General plan

I think start at the end of the spectrum
 > start with very highly correlated (see how many in whole sample)
 > then if big change occurs in short time > react instantly.
^  run whole simulation to test this, leae the above as improv notes for now at bottom of notebook

# %%
# To keep in mind / Future Improvements

# my edge will come from historic data 
#... - (to calculate quantitie sof how much price change + probabilites )

# dont forget EV formulas

# ms data!

# will need a way to run all notebooks and clear all directories

# investigating smaller windows (and other features) and react in 'mini-batches'

# predictive model (ts + volume) to predict how prices may move?
