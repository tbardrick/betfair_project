# %%
import pandas as pd
import json

# %%
data = pd.DataFrame({'t1' : [1,2,3,4,5],
                     't2' : range(0,5)})
data = data.to_dict()

# %%
d = {
    'cor' : 0.95,
    'df' : data,
    'somethign' : 'oubivo'
}

# %%
with open('test.json', 'w') as outfile:
    json.dump(d, outfile, sort_keys=True, indent=4)
    # sort_keys, indent are optional and used for pretty-write

# %%
with open('test.json') as data_file:    
    t = json.load(data_file)

# %%
pd.DataFrame(t['df'])
# Out:
#    t1  t2
# 0   1   0
# 1   2   1
# 2   3   2
# 3   4   3
# 4   5   4

# %%
{'time_period':
 'data_split' : 
 'watch_period':
 'react_period':
 'watch_df':
 'react_df':
 'correlation': 0
 'pairs': [(1,2), (4,5)],
 'var_breach' : some amount var has to be greater than based on mean watch_period['price_dif']}

# %%
create config file for some of this?
