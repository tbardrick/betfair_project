# %%
# import packages
import pandas as pd
import numpy as np
import utils
from pathlib import Path
import os
import glob
import json

# %%
# read in data
def find_pairs(file_name):
    # read in data
    df = pd.read_csv(f'data/{file_name}/{file_name}.csv').astype({'time_sec' : '<M8[ns]'}) # need this?
    
    # keep data X data points before off
    period_mins = 60 # X minutes before off
    watch_pct = 0.8 # X% of period used to train/watch

    # define time slices
    period_max = df.sort_values("time_sec")["time_sec"].tail(1).values[0].copy() # off time
    period_min = period_max - np.timedelta64(period_mins, "m") # 'start' time
    watch_split = period_max - np.timedelta64(round(period_mins * (1 - watch_pct)), "m") # split between watch/act
    
    # keep only times within watch/react
    df = df.loc[(df["time_sec"] > period_min) & (df["time_sec"] < period_max)].copy()
    
    # converting to series
    df_ip = df.pivot(index="time_sec", columns="SelectionId")["imp_prob"]
    df_ip.columns = df_ip.columns.astype(str)

    
    # seperate df into watch/react
    df_ip_watch = df_ip.loc[df_ip.index < watch_split].copy()
    df_ip_watch.index = df_ip_watch.index.astype(str)
    df_ip_react = df_ip.loc[df_ip.index > watch_split].copy()
    df_ip_react.index = df_ip_react.index.astype(str)
    
    # compute correlations
    cor_mat = df_ip_watch.corr()
    
    # find inverse pairs (based on having correlation measure < X)
    cor_min = -0.9
    pairs = utils.getIndexes(cor_mat, cor_min) 
    pairs = list(set([tuple(sorted(t)) for t in pairs]))
    
    # if pairs found in watch period then output
    n_p = len(pairs)
#     print(n_p, pairs)
    
    if  n_p > 0:
        
        print(f'Pairs found = {n_p}. Writing file.')
    
        # making pairs directory for market
        Path(f"data/{file_name}/pairs").mkdir(parents=True, exist_ok=True)

        # compiling data with metadata
        out = {
            'period_mins' : period_mins,
            'watch_pct' : watch_pct,
            'cor_min' : cor_min,
            'watch_df' : df_ip_watch.to_dict(),
            'react_df' : df_ip_react.to_dict(),
            'pairs' : pairs
        }
        
        with open(f'data/{file_name}/pairs/{file_name}.json', 'w') as outfile:
            json.dump(out, outfile, sort_keys=True, indent=4)
        
    else:
        print('No pairs found.')

# %%
# test file?
file_name = '1.169028429'
find_pairs(file_name)
# Out:
# No pairs found.

# %%
df_ip_watch.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-201-2cc546e5a308> in <module>
# ----> 1 df_ip_watch.head()
#
# NameError: name 'df_ip_watch' is not defined

# %% [markdown]
# ---
# ### Identifying pairs from processed

# %%
all_files_path = glob.glob('data/*[!ipynb]')
all_files = [os.path.basename(x) for x in glob.glob('data/*[!ipynb]')]

# %%
n = len(all_files)

for i, f in enumerate(all_files):
    print(f'Screen for pairs in  {f} : {i+1}/{n}')
    
    try:
        find_pairs(f)
        
    except IndexError:
        print('Some index error')
        
    print('\n')
# Out:
# Screen for pairs in  1.169028429 : 1/500
# No pairs found.
#
#
# Screen for pairs in  1.168013705 : 2/500
# No pairs found.
#
#
# Screen for pairs in  1.169341238 : 3/500
# No pairs found.
#
#
# Screen for pairs in  1.168473844 : 4/500
# No pairs found.
#
#
# Screen for pairs in  1.167971949 : 5/500
# No pairs found.
#
#
# Screen for pairs in  1.169057140 : 6/500
# No pairs found.
#
#
# Screen for pairs in  1.169866063 : 7/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.169675383 : 8/500
# No pairs found.
#
#
# Screen for pairs in  1.167449067 : 9/500
# No pairs found.
#
#
# Screen for pairs in  1.170188269 : 10/500
# Some index error
#
#
# Screen for pairs in  1.170070363 : 11/500
# No pairs found.
#
#
# Screen for pairs in  1.168298570 : 12/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.167929665 : 13/500
# No pairs found.
#
#
# Screen for pairs in  1.170070707 : 14/500
# No pairs found.
#
#
# Screen for pairs in  1.167134920 : 15/500
# No pairs found.
#
#
# Screen for pairs in  1.166897828 : 16/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.168618625 : 17/500
# No pairs found.
#
#
# Screen for pairs in  1.167624165 : 18/500
# No pairs found.
#
#
# Screen for pairs in  1.169392263 : 19/500
# Pairs found = 2. Writing file.
#
#
# Screen for pairs in  1.169561935 : 20/500
# No pairs found.
#
#
# Screen for pairs in  1.167108188 : 21/500
# No pairs found.
#
#
# Screen for pairs in  1.168899357 : 22/500
# No pairs found.
#
#
# Screen for pairs in  1.167205819 : 23/500
# No pairs found.
#
#
# Screen for pairs in  1.168758848 : 24/500
# No pairs found.
#
#
# Screen for pairs in  1.169675519 : 25/500
# No pairs found.
#
#
# Screen for pairs in  1.167206230 : 26/500
# No pairs found.
#
#
# Screen for pairs in  1.169201664 : 27/500
# No pairs found.
#
#
# Screen for pairs in  1.168336667 : 28/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.170167255 : 29/500
# No pairs found.
#
#
# Screen for pairs in  1.170118735 : 30/500
# No pairs found.
#
#
# Screen for pairs in  1.167664445 : 31/500
# No pairs found.
#
#
# Screen for pairs in  1.166915306 : 32/500
# No pairs found.
#
#
# Screen for pairs in  1.169668056 : 33/500
# Some index error
#
#
# Screen for pairs in  1.168755339 : 34/500
# No pairs found.
#
#
# Screen for pairs in  1.170180836 : 35/500
# No pairs found.
#
#
# Screen for pairs in  1.167074911 : 36/500
# No pairs found.
#
#
# Screen for pairs in  1.169499207 : 37/500
# No pairs found.
#
#
# Screen for pairs in  1.168392109 : 38/500
# No pairs found.
#
#
# Screen for pairs in  1.169309129 : 39/500
# No pairs found.
#
#
# Screen for pairs in  1.168255043 : 40/500
# No pairs found.
#
#
# Screen for pairs in  1.168061589 : 41/500
# No pairs found.
#
#
# Screen for pairs in  1.169432341 : 42/500
# No pairs found.
#
#
# Screen for pairs in  1.168095599 : 43/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.166915301 : 44/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.168575469 : 45/500
# No pairs found.
#
#
# Screen for pairs in  1.170026973 : 46/500
# No pairs found.
#
#
# Screen for pairs in  1.168431459 : 47/500
# No pairs found.
#
#
# Screen for pairs in  1.170188294 : 48/500
# Some index error
#
#
# Screen for pairs in  1.169558049 : 49/500
# No pairs found.
#
#
# Screen for pairs in  1.169971967 : 50/500
# No pairs found.
#
#
# Screen for pairs in  1.167836957 : 51/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.167971518 : 52/500
# No pairs found.
#
#
# Screen for pairs in  1.169432346 : 53/500
# No pairs found.
#
#
# Screen for pairs in  1.168431466 : 54/500
# No pairs found.
#
#
# Screen for pairs in  1.167074916 : 55/500
# No pairs found.
#
#
# Screen for pairs in  1.167748193 : 56/500
# No pairs found.
#
#
# Screen for pairs in  1.169434613 : 57/500
# No pairs found.
#
#
# Screen for pairs in  1.169668051 : 58/500
# Some index error
#
#
# Screen for pairs in  1.168799528 : 59/500
# No pairs found.
#
#
# Screen for pairs in  1.167206255 : 60/500
# No pairs found.
#
#
# Screen for pairs in  1.167342291 : 61/500
# No pairs found.
#
#
# Screen for pairs in  1.168208888 : 62/500
# No pairs found.
#
#
# Screen for pairs in  1.169561950 : 63/500
# No pairs found.
#
#
# Screen for pairs in  1.169760573 : 64/500
# No pairs found.
#
#
# Screen for pairs in  1.166942600 : 65/500
# No pairs found.
#
#
# Screen for pairs in  1.168799543 : 66/500
# No pairs found.
#
#
# Screen for pairs in  1.167486096 : 67/500
# Pairs found = 2. Writing file.
#
#
# Screen for pairs in  1.167487978 : 68/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.167697075 : 69/500
# No pairs found.
#
#
# Screen for pairs in  1.168287509 : 70/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.166979683 : 71/500
# No pairs found.
#
#
# Screen for pairs in  1.169029303 : 72/500
# No pairs found.
#
#
# Screen for pairs in  1.167342296 : 73/500
# No pairs found.
#
#
# Screen for pairs in  1.169915815 : 74/500
# No pairs found.
#
#
# Screen for pairs in  1.167106084 : 75/500
# No pairs found.
#
#
# Screen for pairs in  1.167486091 : 76/500
# No pairs found.
#
#
# Screen for pairs in  1.168255028 : 77/500
# No pairs found.
#
#
# Screen for pairs in  1.169925677 : 78/500
# No pairs found.
#
#
# Screen for pairs in  1.168939977 : 79/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.168988107 : 80/500
# No pairs found.
#
#
# Screen for pairs in  1.169057125 : 81/500
# No pairs found.
#
#
# Screen for pairs in  1.169392208 : 82/500
# No pairs found.
#
#
# Screen for pairs in  1.168392957 : 83/500
# No pairs found.
#
#
# Screen for pairs in  1.167371620 : 84/500
# No pairs found.
#
#
# Screen for pairs in  1.170181388 : 85/500
# No pairs found.
#
#
# Screen for pairs in  1.167696357 : 86/500
# No pairs found.
#
#
# Screen for pairs in  1.168474003 : 87/500
# No pairs found.
#
#
# Screen for pairs in  1.167106079 : 88/500
# No pairs found.
#
#
# Screen for pairs in  1.169976915 : 89/500
# No pairs found.
#
#
# Screen for pairs in  1.167206600 : 90/500
# No pairs found.
#
#
# Screen for pairs in  1.169619433 : 91/500
# Pairs found = 3. Writing file.
#
#
# Screen for pairs in  1.169157637 : 92/500
# No pairs found.
#
#
# Screen for pairs in  1.169340943 : 93/500
# No pairs found.
#
#
# Screen for pairs in  1.166900014 : 94/500
# No pairs found.
#
#
# Screen for pairs in  1.167390311 : 95/500
# No pairs found.
#
#
# Screen for pairs in  1.168671413 : 96/500
# No pairs found.
#
#
# Screen for pairs in  1.167246329 : 97/500
# No pairs found.
#
#
# Screen for pairs in  1.169500956 : 98/500
# No pairs found.
#
#
# Screen for pairs in  1.169101620 : 99/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.168715440 : 100/500
# No pairs found.
#
#
# Screen for pairs in  1.167487985 : 101/500
# No pairs found.
#
#
# Screen for pairs in  1.168393278 : 102/500
# No pairs found.
#
#
# Screen for pairs in  1.167785097 : 103/500
# No pairs found.
#
#
# Screen for pairs in  1.168575434 : 104/500
# Some index error
#
#
# Screen for pairs in  1.167451007 : 105/500
# No pairs found.
#
#
# Screen for pairs in  1.167108110 : 106/500
# Pairs found = 2. Writing file.
#
#
# Screen for pairs in  1.167243663 : 107/500
# No pairs found.
#
#
# Screen for pairs in  1.166898834 : 108/500
# No pairs found.
#
#
# Screen for pairs in  1.167487971 : 109/500
# No pairs found.
#
#
# Screen for pairs in  1.168473810 : 110/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.170118750 : 111/500
# No pairs found.
#
#
# Screen for pairs in  1.168672433 : 112/500
# No pairs found.
#
#
# Screen for pairs in  1.169500951 : 113/500
# No pairs found.
#
#
# Screen for pairs in  1.169309187 : 114/500
# No pairs found.
#
#
# Screen for pairs in  1.169920596 : 115/500
# No pairs found.
#
#
# Screen for pairs in  1.169057114 : 116/500
# Pairs found = 4. Writing file.
#
#
# Screen for pairs in  1.166897843 : 117/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.167390316 : 118/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.167134513 : 119/500
# No pairs found.
#
#
# Screen for pairs in  1.167176594 : 120/500
# No pairs found.
#
#
# Screen for pairs in  1.167624155 : 121/500
# No pairs found.
#
#
# Screen for pairs in  1.166972808 : 122/500
# No pairs found.
#
#
# Screen for pairs in  1.169260238 : 123/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.168899367 : 124/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.169721740 : 125/500
# No pairs found.
#
#
# Screen for pairs in  1.167205829 : 126/500
# No pairs found.
#
#
# Screen for pairs in  1.167108173 : 127/500
# No pairs found.
#
#
# Screen for pairs in  1.168096580 : 128/500
# No pairs found.
#
#
# Screen for pairs in  1.169675529 : 129/500
# No pairs found.
#
#
# Screen for pairs in  1.167393963 : 130/500
# No pairs found.
#
#
# Screen for pairs in  1.169201654 : 131/500
# No pairs found.
#
#
# Screen for pairs in  1.170167265 : 132/500
# No pairs found.
#
#
# Screen for pairs in  1.170069279 : 133/500
# No pairs found.
#
#
# Screen for pairs in  1.168336657 : 134/500
# No pairs found.
#
#
# Screen for pairs in  1.169028419 : 135/500
# No pairs found.
#
#
# Screen for pairs in  1.168062590 : 136/500
# No pairs found.
#
#
# Screen for pairs in  1.168473874 : 137/500
# No pairs found.
#
#
# Screen for pairs in  1.168715047 : 138/500
# No pairs found.
#
#
# Screen for pairs in  1.169760713 : 139/500
# No pairs found.
#
#
# Screen for pairs in  1.169866053 : 140/500
# No pairs found.
#
#
# Screen for pairs in  1.167449057 : 141/500
# No pairs found.
#
#
# Screen for pairs in  1.167061899 : 142/500
# No pairs found.
#
#
# Screen for pairs in  1.168431494 : 143/500
# No pairs found.
#
#
# Screen for pairs in  1.169675378 : 144/500
# No pairs found.
#
#
# Screen for pairs in  1.168298540 : 145/500
# No pairs found.
#
#
# Screen for pairs in  1.167929655 : 146/500
# No pairs found.
#
#
# Screen for pairs in  1.168096573 : 147/500
# No pairs found.
#
#
# Screen for pairs in  1.168096587 : 148/500
# No pairs found.
#
#
# Screen for pairs in  1.168618615 : 149/500
# No pairs found.
#
#
# Screen for pairs in  1.168988509 : 150/500
# No pairs found.
#
#
# Screen for pairs in  1.167134910 : 151/500
# No pairs found.
#
#
# Screen for pairs in  1.168575459 : 152/500
# No pairs found.
#
#
# Screen for pairs in  1.169927371 : 153/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.169558079 : 154/500
# No pairs found.
#
#
# Screen for pairs in  1.167836967 : 155/500
# No pairs found.
#
#
# Screen for pairs in  1.169760528 : 156/500
# No pairs found.
#
#
# Screen for pairs in  1.168473889 : 157/500
# No pairs found.
#
#
# Screen for pairs in  1.167074926 : 158/500
# No pairs found.
#
#
# Screen for pairs in  1.167829711 : 159/500
# No pairs found.
#
#
# Screen for pairs in  1.168799518 : 160/500
# No pairs found.
#
#
# Screen for pairs in  1.169668061 : 161/500
# Some index error
#
#
# Screen for pairs in  1.169434623 : 162/500
# No pairs found.
#
#
# Screen for pairs in  1.170069284 : 163/500
# No pairs found.
#
#
# Screen for pairs in  1.169927376 : 164/500
# No pairs found.
#
#
# Screen for pairs in  1.170118705 : 165/500
# No pairs found.
#
#
# Screen for pairs in  1.167831510 : 166/500
# No pairs found.
#
#
# Screen for pairs in  1.167787598 : 167/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.168203090 : 168/500
# No pairs found.
#
#
# Screen for pairs in  1.169668066 : 169/500
# Some index error
#
#
# Screen for pairs in  1.167074921 : 170/500
# No pairs found.
#
#
# Screen for pairs in  1.169309119 : 171/500
# No pairs found.
#
#
# Screen for pairs in  1.168298585 : 172/500
# No pairs found.
#
#
# Screen for pairs in  1.167246344 : 173/500
# No pairs found.
#
#
# Screen for pairs in  1.167881247 : 174/500
# No pairs found.
#
#
# Screen for pairs in  1.169029333 : 175/500
# No pairs found.
#
#
# Screen for pairs in  1.166979647 : 176/500
# No pairs found.
#
#
# Screen for pairs in  1.169915825 : 177/500
# No pairs found.
#
#
# Screen for pairs in  1.168937485 : 178/500
# No pairs found.
#
#
# Screen for pairs in  1.168988137 : 179/500
# No pairs found.
#
#
# Screen for pairs in  1.169667277 : 180/500
# No pairs found.
#
#
# Screen for pairs in  1.168130666 : 181/500
# No pairs found.
#
#
# Screen for pairs in  1.169056691 : 182/500
# No pairs found.
#
#
# Screen for pairs in  1.167371887 : 183/500
# No pairs found.
#
#
# Screen for pairs in  1.169866204 : 184/500
# No pairs found.
#
#
# Screen for pairs in  1.166979678 : 185/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.168393246 : 186/500
# No pairs found.
#
#
# Screen for pairs in  1.167971924 : 187/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.168893263 : 188/500
# No pairs found.
#
#
# Screen for pairs in  1.169971903 : 189/500
# No pairs found.
#
#
# Screen for pairs in  1.168208873 : 190/500
# No pairs found.
#
#
# Screen for pairs in  1.169809701 : 191/500
# No pairs found.
#
#
# Screen for pairs in  1.169561960 : 192/500
# No pairs found.
#
#
# Screen for pairs in  1.168393241 : 193/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.169309181 : 194/500
# No pairs found.
#
#
# Screen for pairs in  1.166942630 : 195/500
# No pairs found.
#
#
# Screen for pairs in  1.169760543 : 196/500
# No pairs found.
#
#
# Screen for pairs in  1.168336867 : 197/500
# No pairs found.
#
#
# Screen for pairs in  1.169056696 : 198/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.168130661 : 199/500
# No pairs found.
#
#
# Screen for pairs in  1.168014740 : 200/500
# No pairs found.
#
#
# Screen for pairs in  1.168799573 : 201/500
# No pairs found.
#
#
# Screen for pairs in  1.167624130 : 202/500
# No pairs found.
#
#
# Screen for pairs in  1.170099499 : 203/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.169808288 : 204/500
# No pairs found.
#
#
# Screen for pairs in  1.168571898 : 205/500
# No pairs found.
#
#
# Screen for pairs in  1.167697080 : 206/500
# No pairs found.
#
#
# Screen for pairs in  1.166898804 : 207/500
# No pairs found.
#
#
# Screen for pairs in  1.167108120 : 208/500
# No pairs found.
#
#
# Screen for pairs in  1.168431434 : 209/500
# No pairs found.
#
#
# Screen for pairs in  1.168473820 : 210/500
# No pairs found.
#
#
# Screen for pairs in  1.168393283 : 211/500
# No pairs found.
#
#
# Screen for pairs in  1.169927777 : 212/500
# No pairs found.
#
#
# Screen for pairs in  1.167390326 : 213/500
# No pairs found.
#
#
# Screen for pairs in  1.167134523 : 214/500
# No pairs found.
#
#
# Screen for pairs in  1.169155739 : 215/500
# No pairs found.
#
#
# Screen for pairs in  1.167696367 : 216/500
# No pairs found.
#
#
# Screen for pairs in  1.167206630 : 217/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.169976925 : 218/500
# No pairs found.
#
#
# Screen for pairs in  1.169340973 : 219/500
# No pairs found.
#
#
# Screen for pairs in  1.166900024 : 220/500
# No pairs found.
#
#
# Screen for pairs in  1.168671423 : 221/500
# No pairs found.
#
#
# Screen for pairs in  1.169309144 : 222/500
# No pairs found.
#
#
# Screen for pairs in  1.167390321 : 223/500
# No pairs found.
#
#
# Screen for pairs in  1.169101610 : 224/500
# No pairs found.
#
#
# Screen for pairs in  1.168336924 : 225/500
# No pairs found.
#
#
# Screen for pairs in  1.167106104 : 226/500
# No pairs found.
#
#
# Screen for pairs in  1.167486111 : 227/500
# No pairs found.
#
#
# Screen for pairs in  1.169392375 : 228/500
# No pairs found.
#
#
# Screen for pairs in  1.166898724 : 229/500
# No pairs found.
#
#
# Screen for pairs in  1.168523559 : 230/500
# No pairs found.
#
#
# Screen for pairs in  1.169056721 : 231/500
# No pairs found.
#
#
# Screen for pairs in  1.168287489 : 232/500
# No pairs found.
#
#
# Screen for pairs in  1.168759044 : 233/500
# No pairs found.
#
#
# Screen for pairs in  1.170188181 : 234/500
# Some index error
#
#
# Screen for pairs in  1.167755357 : 235/500
# No pairs found.
#
#
# Screen for pairs in  1.167787649 : 236/500
# No pairs found.
#
#
# Screen for pairs in  1.167521971 : 237/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.167486116 : 238/500
# No pairs found.
#
#
# Screen for pairs in  1.169340698 : 239/500
# No pairs found.
#
#
# Screen for pairs in  1.167488047 : 240/500
# No pairs found.
#
#
# Screen for pairs in  1.168524744 : 241/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.170021047 : 242/500
# No pairs found.
#
#
# Screen for pairs in  1.167300998 : 243/500
# No pairs found.
#
#
# Screen for pairs in  1.166972788 : 244/500
# No pairs found.
#
#
# Screen for pairs in  1.170188186 : 245/500
# Some index error
#
#
# Screen for pairs in  1.169057069 : 246/500
# No pairs found.
#
#
# Screen for pairs in  1.168133506 : 247/500
# No pairs found.
#
#
# Screen for pairs in  1.169057094 : 248/500
# No pairs found.
#
#
# Screen for pairs in  1.167134493 : 249/500
# No pairs found.
#
#
# Screen for pairs in  1.169721657 : 250/500
# No pairs found.
#
#
# Screen for pairs in  1.169432439 : 251/500
# No pairs found.
#
#
# Screen for pairs in  1.167709826 : 252/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.167626940 : 253/500
# Pairs found = 2. Writing file.
#
#
# Screen for pairs in  1.167785117 : 254/500
# No pairs found.
#
#
# Screen for pairs in  1.167142048 : 255/500
# No pairs found.
#
#
# Screen for pairs in  1.168759075 : 256/500
# No pairs found.
#
#
# Screen for pairs in  1.169393639 : 257/500
# No pairs found.
#
#
# Screen for pairs in  1.167967933 : 258/500
# No pairs found.
#
#
# Screen for pairs in  1.167176619 : 259/500
# No pairs found.
#
#
# Screen for pairs in  1.167709821 : 260/500
# No pairs found.
#
#
# Screen for pairs in  1.169103003 : 261/500
# No pairs found.
#
#
# Screen for pairs in  1.167205798 : 262/500
# No pairs found.
#
#
# Screen for pairs in  1.167181844 : 263/500
# No pairs found.
#
#
# Screen for pairs in  1.167934660 : 264/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.168902610 : 265/500
# No pairs found.
#
#
# Screen for pairs in  1.168133501 : 266/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.167756528 : 267/500
# No pairs found.
#
#
# Screen for pairs in  1.169028393 : 268/500
# No pairs found.
#
#
# Screen for pairs in  1.170166637 : 269/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.169619345 : 270/500
# No pairs found.
#
#
# Screen for pairs in  1.168846821 : 271/500
# No pairs found.
#
#
# Screen for pairs in  1.167787613 : 272/500
# No pairs found.
#
#
# Screen for pairs in  1.168433274 : 273/500
# No pairs found.
#
#
# Screen for pairs in  1.166898779 : 274/500
# No pairs found.
#
#
# Screen for pairs in  1.166899499 : 275/500
# No pairs found.
#
#
# Screen for pairs in  1.167576026 : 276/500
# No pairs found.
#
#
# Screen for pairs in  1.167485957 : 277/500
# No pairs found.
#
#
# Screen for pairs in  1.167878469 : 278/500
# No pairs found.
#
#
# Screen for pairs in  1.167629990 : 279/500
# No pairs found.
#
#
# Screen for pairs in  1.169341945 : 280/500
# No pairs found.
#
#
# Screen for pairs in  1.167177559 : 281/500
# No pairs found.
#
#
# Screen for pairs in  1.170070687 : 282/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.167076169 : 283/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.167488217 : 284/500
# No pairs found.
#
#
# Screen for pairs in  1.166913943 : 285/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.170097628 : 286/500
# No pairs found.
#
#
# Screen for pairs in  1.170099574 : 287/500
# No pairs found.
#
#
# Screen for pairs in  1.168846826 : 288/500
# No pairs found.
#
#
# Screen for pairs in  1.168674274 : 289/500
# No pairs found.
#
#
# Screen for pairs in  1.169619389 : 290/500
# No pairs found.
#
#
# Screen for pairs in  1.168524719 : 291/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.168013685 : 292/500
# No pairs found.
#
#
# Screen for pairs in  1.167662055 : 293/500
# No pairs found.
#
#
# Screen for pairs in  1.167629963 : 294/500
# No pairs found.
#
#
# Screen for pairs in  1.167343058 : 295/500
# No pairs found.
#
#
# Screen for pairs in  1.169721603 : 296/500
# No pairs found.
#
#
# Screen for pairs in  1.169057034 : 297/500
# No pairs found.
#
#
# Screen for pairs in  1.167142023 : 298/500
# No pairs found.
#
#
# Screen for pairs in  1.168800254 : 299/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.168095614 : 300/500
# No pairs found.
#
#
# Screen for pairs in  1.166919641 : 301/500
# No pairs found.
#
#
# Screen for pairs in  1.167971498 : 302/500
# No pairs found.
#
#
# Screen for pairs in  1.170188314 : 303/500
# Some index error
#
#
# Screen for pairs in  1.167923813 : 304/500
# No pairs found.
#
#
# Screen for pairs in  1.167206375 : 305/500
# No pairs found.
#
#
# Screen for pairs in  1.170025447 : 306/500
# Pairs found = 2. Writing file.
#
#
# Screen for pairs in  1.169619374 : 307/500
# No pairs found.
#
#
# Screen for pairs in  1.168298600 : 308/500
# No pairs found.
#
#
# Screen for pairs in  1.168754708 : 309/500
# No pairs found.
#
#
# Screen for pairs in  1.167243781 : 310/500
# No pairs found.
#
#
# Screen for pairs in  1.169341980 : 311/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.166944047 : 312/500
# No pairs found.
#
#
# Screen for pairs in  1.168136224 : 313/500
# No pairs found.
#
#
# Screen for pairs in  1.166915281 : 314/500
# No pairs found.
#
#
# Screen for pairs in  1.170099589 : 315/500
# No pairs found.
#
#
# Screen for pairs in  1.166973067 : 316/500
# Pairs found = 2. Writing file.
#
#
# Screen for pairs in  1.169102988 : 317/500
# No pairs found.
#
#
# Screen for pairs in  1.167076194 : 318/500
# No pairs found.
#
#
# Screen for pairs in  1.167181821 : 319/500
# No pairs found.
#
#
# Screen for pairs in  1.167666437 : 320/500
# No pairs found.
#
#
# Screen for pairs in  1.167451324 : 321/500
# No pairs found.
#
#
# Screen for pairs in  1.170025440 : 322/500
# No pairs found.
#
#
# Screen for pairs in  1.167524205 : 323/500
# Pairs found = 2. Writing file.
#
#
# Screen for pairs in  1.168845468 : 324/500
# Some index error
#
#
# Screen for pairs in  1.167626925 : 325/500
# No pairs found.
#
#
# Screen for pairs in  1.167829004 : 326/500
# No pairs found.
#
#
# Screen for pairs in  1.168431515 : 327/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.166919646 : 328/500
# No pairs found.
#
#
# Screen for pairs in  1.167878494 : 329/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.167181826 : 330/500
# No pairs found.
#
#
# Screen for pairs in  1.166898784 : 331/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.169947575 : 332/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.170181403 : 333/500
# No pairs found.
#
#
# Screen for pairs in  1.168433289 : 334/500
# No pairs found.
#
#
# Screen for pairs in  1.168061604 : 335/500
# No pairs found.
#
#
# Screen for pairs in  1.168133563 : 336/500
# No pairs found.
#
#
# Screen for pairs in  1.166915286 : 337/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.169056716 : 338/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.167755367 : 339/500
# No pairs found.
#
#
# Screen for pairs in  1.167521941 : 340/500
# No pairs found.
#
#
# Screen for pairs in  1.169971848 : 341/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.167206578 : 342/500
# No pairs found.
#
#
# Screen for pairs in  1.169808308 : 343/500
# No pairs found.
#
#
# Screen for pairs in  1.167828989 : 344/500
# No pairs found.
#
#
# Screen for pairs in  1.169432090 : 345/500
# No pairs found.
#
#
# Screen for pairs in  1.169809681 : 346/500
# No pairs found.
#
#
# Screen for pairs in  1.169057059 : 347/500
# No pairs found.
#
#
# Screen for pairs in  1.167709023 : 348/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.166947655 : 349/500
# No pairs found.
#
#
# Screen for pairs in  1.168336914 : 350/500
# No pairs found.
#
#
# Screen for pairs in  1.168937505 : 351/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.167521946 : 352/500
# No pairs found.
#
#
# Screen for pairs in  1.168095648 : 353/500
# No pairs found.
#
#
# Screen for pairs in  1.169056711 : 354/500
# No pairs found.
#
#
# Screen for pairs in  1.166898714 : 355/500
# No pairs found.
#
#
# Screen for pairs in  1.168523569 : 356/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.169809686 : 357/500
# No pairs found.
#
#
# Screen for pairs in  1.168758704 : 358/500
# Pairs found = 3. Writing file.
#
#
# Screen for pairs in  1.170139935 : 359/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.169866189 : 360/500
# No pairs found.
#
#
# Screen for pairs in  1.167709811 : 361/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.167451349 : 362/500
# No pairs found.
#
#
# Screen for pairs in  1.169028368 : 363/500
# No pairs found.
#
#
# Screen for pairs in  1.169866174 : 364/500
# No pairs found.
#
#
# Screen for pairs in  1.166942547 : 365/500
# No pairs found.
#
#
# Screen for pairs in  1.167181874 : 366/500
# No pairs found.
#
#
# Screen for pairs in  1.168759089 : 367/500
# No pairs found.
#
#
# Screen for pairs in  1.168847736 : 368/500
# No pairs found.
#
#
# Screen for pairs in  1.168902620 : 369/500
# No pairs found.
#
#
# Screen for pairs in  1.167934650 : 370/500
# No pairs found.
#
#
# Screen for pairs in  1.167756518 : 371/500
# No pairs found.
#
#
# Screen for pairs in  1.169028357 : 372/500
# No pairs found.
#
#
# Screen for pairs in  1.168473998 : 373/500
# No pairs found.
#
#
# Screen for pairs in  1.168847731 : 374/500
# No pairs found.
#
#
# Screen for pairs in  1.169721667 : 375/500
# No pairs found.
#
#
# Screen for pairs in  1.168393303 : 376/500
# No pairs found.
#
#
# Screen for pairs in  1.167828974 : 377/500
# No pairs found.
#
#
# Screen for pairs in  1.167775590 : 378/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.167709816 : 379/500
# No pairs found.
#
#
# Screen for pairs in  1.169392380 : 380/500
# No pairs found.
#
#
# Screen for pairs in  1.167697100 : 381/500
# No pairs found.
#
#
# Screen for pairs in  1.167629938 : 382/500
# No pairs found.
#
#
# Screen for pairs in  1.167390609 : 383/500
# No pairs found.
#
#
# Screen for pairs in  1.170117697 : 384/500
# No pairs found.
#
#
# Screen for pairs in  1.168571918 : 385/500
# No pairs found.
#
#
# Screen for pairs in  1.167785127 : 386/500
# No pairs found.
#
#
# Screen for pairs in  1.168431540 : 387/500
# No pairs found.
#
#
# Screen for pairs in  1.167206571 : 388/500
# No pairs found.
#
#
# Screen for pairs in  1.167967903 : 389/500
# No pairs found.
#
#
# Screen for pairs in  1.169393609 : 390/500
# No pairs found.
#
#
# Screen for pairs in  1.167177569 : 391/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.170097618 : 392/500
# No pairs found.
#
#
# Screen for pairs in  1.166913973 : 393/500
# Pairs found = 3. Writing file.
#
#
# Screen for pairs in  1.167488227 : 394/500
# No pairs found.
#
#
# Screen for pairs in  1.168988489 : 395/500
# No pairs found.
#
#
# Screen for pairs in  1.168846816 : 396/500
# No pairs found.
#
#
# Screen for pairs in  1.169947580 : 397/500
# No pairs found.
#
#
# Screen for pairs in  1.169760693 : 398/500
# No pairs found.
#
#
# Screen for pairs in  1.168524729 : 399/500
# No pairs found.
#
#
# Screen for pairs in  1.169309407 : 400/500
# No pairs found.
#
#
# Screen for pairs in  1.167629953 : 401/500
# No pairs found.
#
#
# Screen for pairs in  1.167662065 : 402/500
# No pairs found.
#
#
# Screen for pairs in  1.167343068 : 403/500
# No pairs found.
#
#
# Screen for pairs in  1.166947630 : 404/500
# Pairs found = 2. Writing file.
#
#
# Screen for pairs in  1.168800264 : 405/500
# No pairs found.
#
#
# Screen for pairs in  1.168846811 : 406/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.168620964 : 407/500
# No pairs found.
#
#
# Screen for pairs in  1.168759016 : 408/500
# No pairs found.
#
#
# Screen for pairs in  1.167787623 : 409/500
# No pairs found.
#
#
# Screen for pairs in  1.167485967 : 410/500
# No pairs found.
#
#
# Screen for pairs in  1.167206380 : 411/500
# No pairs found.
#
#
# Screen for pairs in  1.170118647 : 412/500
# No pairs found.
#
#
# Screen for pairs in  1.169341975 : 413/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.169211579 : 414/500
# No pairs found.
#
#
# Screen for pairs in  1.168988677 : 415/500
# No pairs found.
#
#
# Screen for pairs in  1.167366745 : 416/500
# No pairs found.
#
#
# Screen for pairs in  1.167829696 : 417/500
# No pairs found.
#
#
# Screen for pairs in  1.169211584 : 418/500
# No pairs found.
#
#
# Screen for pairs in  1.168845458 : 419/500
# No pairs found.
#
#
# Screen for pairs in  1.168431525 : 420/500
# No pairs found.
#
#
# Screen for pairs in  1.168013670 : 421/500
# No pairs found.
#
#
# Screen for pairs in  1.167394207 : 422/500
# No pairs found.
#
#
# Screen for pairs in  1.167181816 : 423/500
# No pairs found.
#
#
# Screen for pairs in  1.169309260 : 424/500
# No pairs found.
#
#
# Screen for pairs in  1.168133553 : 425/500
# No pairs found.
#
#
# Screen for pairs in  1.170118685 : 426/500
# No pairs found.
#
#
# Screen for pairs in  1.168060376 : 427/500
# No pairs found.
#
#
# Screen for pairs in  1.167831490 : 428/500
# No pairs found.
#
#
# Screen for pairs in  1.170188324 : 429/500
# Some index error
#
#
# Screen for pairs in  1.168473909 : 430/500
# No pairs found.
#
#
# Screen for pairs in  1.167923823 : 431/500
# No pairs found.
#
#
# Screen for pairs in  1.167829691 : 432/500
# No pairs found.
#
#
# Screen for pairs in  1.169432454 : 433/500
# No pairs found.
#
#
# Screen for pairs in  1.168060371 : 434/500
# No pairs found.
#
#
# Screen for pairs in  1.168136214 : 435/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.168902645 : 436/500
# No pairs found.
#
#
# Screen for pairs in  1.167709048 : 437/500
# No pairs found.
#
#
# Screen for pairs in  1.166973057 : 438/500
# No pairs found.
#
#
# Screen for pairs in  1.167181811 : 439/500
# No pairs found.
#
#
# Screen for pairs in  1.169260199 : 440/500
# No pairs found.
#
#
# Screen for pairs in  1.170097633 : 441/500
# No pairs found.
#
#
# Screen for pairs in  1.166913958 : 442/500
# No pairs found.
#
#
# Screen for pairs in  1.168473914 : 443/500
# No pairs found.
#
#
# Screen for pairs in  1.169432449 : 444/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.167520811 : 445/500
# No pairs found.
#
#
# Screen for pairs in  1.167524210 : 446/500
# No pairs found.
#
#
# Screen for pairs in  1.167626930 : 447/500
# Some index error
#
#
# Screen for pairs in  1.167366760 : 448/500
# No pairs found.
#
#
# Screen for pairs in  1.167142038 : 449/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.169721618 : 450/500
# Pairs found = 2. Writing file.
#
#
# Screen for pairs in  1.170070657 : 451/500
# No pairs found.
#
#
# Screen for pairs in  1.167520816 : 452/500
# No pairs found.
#
#
# Screen for pairs in  1.168988697 : 453/500
# No pairs found.
#
#
# Screen for pairs in  1.169341995 : 454/500
# No pairs found.
#
#
# Screen for pairs in  1.167301008 : 455/500
# No pairs found.
#
#
# Screen for pairs in  1.167787608 : 456/500
# No pairs found.
#
#
# Screen for pairs in  1.167206360 : 457/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.169432471 : 458/500
# No pairs found.
#
#
# Screen for pairs in  1.167206536 : 459/500
# No pairs found.
#
#
# Screen for pairs in  1.168620984 : 460/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.167488006 : 461/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.170166647 : 462/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.169309280 : 463/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.168620979 : 464/500
# No pairs found.
#
#
# Screen for pairs in  1.167450817 : 465/500
# No pairs found.
#
#
# Screen for pairs in  1.168845473 : 466/500
# Some index error
#
#
# Screen for pairs in  1.167662040 : 467/500
# No pairs found.
#
#
# Screen for pairs in  1.168013690 : 468/500
# No pairs found.
#
#
# Screen for pairs in  1.169211564 : 469/500
# No pairs found.
#
#
# Screen for pairs in  1.167829676 : 470/500
# No pairs found.
#
#
# Screen for pairs in  1.167243756 : 471/500
# No pairs found.
#
#
# Screen for pairs in  1.168062600 : 472/500
# No pairs found.
#
#
# Screen for pairs in  1.167177574 : 473/500
# No pairs found.
#
#
# Screen for pairs in  1.167787639 : 474/500
# No pairs found.
#
#
# Screen for pairs in  1.170099559 : 475/500
# No pairs found.
#
#
# Screen for pairs in  1.168754713 : 476/500
# No pairs found.
#
#
# Screen for pairs in  1.168988494 : 477/500
# No pairs found.
#
#
# Screen for pairs in  1.167629985 : 478/500
# No pairs found.
#
#
# Screen for pairs in  1.167923808 : 479/500
# No pairs found.
#
#
# Screen for pairs in  1.169341950 : 480/500
# No pairs found.
#
#
# Screen for pairs in  1.167243751 : 481/500
# No pairs found.
#
#
# Screen for pairs in  1.168674259 : 482/500
# No pairs found.
#
#
# Screen for pairs in  1.167488037 : 483/500
# No pairs found.
#
#
# Screen for pairs in  1.170021037 : 484/500
# No pairs found.
#
#
# Screen for pairs in  1.168524734 : 485/500
# No pairs found.
#
#
# Screen for pairs in  1.169619350 : 486/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.169057019 : 487/500
# No pairs found.
#
#
# Screen for pairs in  1.168800279 : 488/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.167061904 : 489/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.169102993 : 490/500
# Pairs found = 1. Writing file.
#
#
# Screen for pairs in  1.166919631 : 491/500
# Pairs found = 2. Writing file.
#
#
# Screen for pairs in  1.169056957 : 492/500
# No pairs found.
#
#
# Screen for pairs in  1.169809661 : 493/500
# No pairs found.
#
#
# Screen for pairs in  1.168264297 : 494/500
# No pairs found.
#
#
# Screen for pairs in  1.169971863 : 495/500
# Pairs found = 2. Writing file.
#
#
# Screen for pairs in  1.169340683 : 496/500
# No pairs found.
#
#
# Screen for pairs in  1.167828969 : 497/500
# No pairs found.
#
#
# Screen for pairs in  1.167300983 : 498/500
# No pairs found.
#
#
# Screen for pairs in  1.167390614 : 499/500
# No pairs found.
#
#
# Screen for pairs in  1.167934675 : 500/500
# No pairs found.

# %%
# Improvements
# Data analysis - 'market types' where this happends most (clustering) e.g. where two main market leaders

# Way to reduce correlation matirx size - speed!

# granger causality?

# cor_matric - indexes func - # is this efficient? ideal would be to remove duplicates from matrix

# add in something to say no pairs found 

# clear directories to write new files for different correlation levels

# write out only columns which are pairs

# %% [markdown]
# ---

# %%
# for d in all_files:
#     print(f"data/{d}/pairs/")
#     try:
#         print('remove pairs data if exists')
#         os.remove(f"data/{d}/pairs/*")
        
#         print('remove pairs directory')
#         os.rmdir(f"data/{d}/pairs")
            
#     except FileNotFoundError:
#         print('File never written')

# %%
# remove pairs data
